# %%
import numpy as np
import pandas as pd

import astropy.units as u
from astropy import coordinates, units as u, wcs
from astropy.io.votable import parse
from astropy.table import Table, Column, QTable
from astropy.io import fits
from astropy.visualization import simple_norm


from ipyaladin import Aladin
from ipywidgets import Layout, Box, widgets
import ipyaladin.aladin_widget as ipyal
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

from astroquery.gaia import Gaia
from astroquery.vizier import Vizier

from astropy.wcs import WCS
from astropy.wcs.utils import skycoord_to_pixel
from astropy.nddata import CCDData
from astropy.coordinates import SkyCoord

import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from matplotlib.patches import Rectangle
from matplotlib.patches import Polygon


import importlib 

from skimage import transform


# %matplotlib notebook
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %% [markdown]
# # We want to create a DMD slit pattern for a certain FoV using GAIA data

# %%
# import functions to do stuff
import setup_obs_functions as sof

# %%
t1 = pd.read_csv("test_pattern1_92.03352_24.35393.dat",index_col=False)
t2 = pd.read_csv("test_pattern2_92.03352_24.35393.dat",index_col=False)

t1 = t1.drop(columns=t1.columns[0])
t2 = t2.drop(columns=t2.columns[0])

t1.target[0][:9]+t1.target[0][-5:]

t1['target'] = np.asarray([i[:9]+i[-5:] for i in t1.target.values ])
t2['target'] = np.asarray([i[:9]+i[-5:] for i in t2.target.values ])

t2
# Out:
#            target        ra       dec    x    y  dx1  dy1  dx2  dy2
# 0  Gaia DR2 65472  92.04723  24.35610  277  584   32    1   32    1
# 1  Gaia DR2 09920  92.04154  24.35012  386  459   36    1   36    1
# 2  Gaia DR2 72800  92.02549  24.37472  692  974   41    1   41    1
# 3  Gaia DR2 14176  92.02378  24.37161  724  909   36    1   36    1

# %%
t1f = t1.style.format({"ra": "{:.5f}",
                 "dec": "{:.5f}",
                 "x": "{:.0f}",
                 "y": "{:.0f}",
                 "dx1": "{:.0f}",
                 "dy1": "{:.0f}",
                 "dx2": "{:.0f}",
                 "dy2": "{:.0f}"})

t2f = t2.style.format({"ra": "{:.5f}",
                 "dec": "{:.5f}",
                 "x": "{:.0f}",
                 "y": "{:.0f}",
                 "dx1": "{:.0f}",
                 "dy1": "{:.0f}",
                 "dx2": "{:.0f}",
                 "dy2": "{:.0f}"})



t1['x'] = t1['x'].astype('int')
t1['y'] = t1['y'].astype('int')
t1['dx1'] = t1['dx1'].astype('int')
t1['dy1'] = t1['dy1'].astype('int')
t1['dx2'] = t1['dx2'].astype('int')
t1['dy2'] = t1['dy2'].astype('int')

t2['x'] = t1['x'].astype('int')
t2['y'] = t1['y'].astype('int')
t2['dx1'] = t2['dx1'].astype('int')
t2['dy1'] = t2['dy1'].astype('int')
t2['dx2'] = t2['dx2'].astype('int')
t2['dy2'] = t2['dy2'].astype('int')


t1.to_csv("test_pattern1_92.03352_24.35393.dat",float_format="%.5f")
t2.to_csv("test_pattern2_92.03352_24.35393.dat",float_format="%.5f")

# %%
# test coordinates are from a SAMI image I've been using

RA = '06:08:8.455'                                                         
DEC = '24:20:55.14'
coords = SkyCoord(RA,DEC,unit=(u.hourangle,u.degree), frame='icrs')

width = u.Quantity(4., u.arcmin)
height = u.Quantity(4., u.arcmin)
vizgal = Vizier.query_region(coords, width=width,height=height)
 
print("coords=",coords)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/7t/yf4p3jc93t5dhyzmjpcn802h0000gn/T/ipykernel_5939/932173651.py in <module>
#       7 width = u.Quantity(4., u.arcmin)
#       8 height = u.Quantity(4., u.arcmin)
# ----> 9 vizgal = Vizier.query_region(coords, width=width,height=height)
#      10
#      11 print("coords=",coords)
#
# /opt/anaconda3/envs/astroconda2/lib/python3.7/site-packages/astroquery/utils/class_or_instance.py in f(*args, **kwds)
#      23         def f(*args, **kwds):
#      24             if obj is not None:
# ---> 25                 return self.fn(obj, *args, **kwds)
#      26             else:
#      27                 return self.fn(cls, *args, **kwds)
#
# /opt/anaconda3/envs/astroconda2/lib/python3.7/site-packages/astroquery/utils/process_asyncs.py in newmethod(self, *args, **kwargs)
#      24             verbose = kwargs.pop('verbose', False)
#      25
# ---> 26             response = getattr(self, async_method_name)(*args, **kwargs)
#      27             if kwargs.get('get_query_payload') or kwargs.get('field_help'):
#      28                 return response
#
# /opt/anaconda3/envs/astroconda2/lib/python3.7/site-packages/astroquery/vizier/core.py in query_region_async(self, coordinates, radius, inner_radius, width, height, catalog, get_query_payload, cache, return_type)
#     440         response = self._request(
#     441             method='POST', url=self._server_to_url(return_type=return_type),
# --> 442             data=data_payload, timeout=self.TIMEOUT, cache=cache)
#     443         return response
#     444
#
# /opt/anaconda3/envs/astroconda2/lib/python3.7/site-packages/astroquery/query.py in _request(self, method, url, params, data, headers, files, save, savedir, timeout, cache, stream, auth, continuation, verify)
#     244                                              stream=stream,
#     245                                              auth=auth,
# --> 246                                              verify=verify)
#     247                     to_cache(response, query.request_file(self.cache_location))
#     248             self._last_query = query
#
# /opt/anaconda3/envs/astroconda2/lib/python3.7/site-packages/astroquery/query.py in request(self, session, cache_location, stream, auth, verify)
#      64                                data=self.data, headers=self.headers,
#      65                                files=self.files, timeout=self.timeout,
# ---> 66                                stream=stream, auth=auth, verify=verify)
#      67
#      68     def hash(self):
#
# /opt/anaconda3/envs/astroconda2/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# /opt/anaconda3/envs/astroconda2/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     685
#     686         if not stream:
# --> 687             r.content
#     688
#     689         return r
#
# /opt/anaconda3/envs/astroconda2/lib/python3.7/site-packages/requests/models.py in content(self)
#     836                 self._content = None
#     837             else:
# --> 838                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     839
#     840         self._content_consumed = True
#
# /opt/anaconda3/envs/astroconda2/lib/python3.7/site-packages/requests/models.py in generate()
#     758             if hasattr(self.raw, 'stream'):
#     759                 try:
# --> 760                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     761                         yield chunk
#     762                 except ProtocolError as e:
#
# /opt/anaconda3/envs/astroconda2/lib/python3.7/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     570         """
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#     574         else:
#
# /opt/anaconda3/envs/astroconda2/lib/python3.7/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     762
#     763             while True:
# --> 764                 self._update_chunk_length()
#     765                 if self.chunk_left == 0:
#     766                     break
#
# /opt/anaconda3/envs/astroconda2/lib/python3.7/site-packages/urllib3/response.py in _update_chunk_length(self)
#     692         if self.chunk_left is not None:
#     693             return
# --> 694         line = self._fp.fp.readline()
#     695         line = line.split(b";", 1)[0]
#     696         try:
#
# /opt/anaconda3/envs/astroconda2/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# General field of view we are looking for can be shown by aladin


### NOTICE HOW THE IMAGES ARE FLIPPED IN X/RA ###

fov = 4*u.arcmin
aladin = ipyal.Aladin(target=coords.to_string(), fov=fov.to(u.degree).to_value(), survey='DSS')

aladin
# Out:
# Aladin(fov=0.06666666666666667, options=['allow_full_zoomout', 'coo_frame', 'fov', 'full_screen', 'log', 'over…

# %% [markdown]
# # Gaia query
#
# We have a field of stars on which we wish to center slits made by the DMD.
#
# We need Gaia astrometry for this, so select sets of stars to observe based on a Gaia query.
# Link to info about returned tables: https://gea.esac.esa.int/archive/documentation/GDR2/Gaia_archive/chap_datamodel/sec_dm_main_tables/ssec_dm_gaia_source.html
#
# Passbands:\
# Full G-band (330–1050 nm) 	\
# GBP-band (330–680 nm) - bluer \
# GRP-band (630–1050 nm) - redder
#
# Blue-Red color column is 'bp_rp', larger number means redder (faint in blue, bright in red)

# %%
importlib.reload(sof)
# GAIA query routine is in setup_obs_functions
table1 = sof.submit_gaia_query(coords)


# Pick some criteria for targets so that we aren't overwhelmed
pandacat = table1.to_pandas().drop(columns='index')
criteria=(pandacat['phot_bp_mean_mag'] > 10) & (pandacat['phot_rp_mean_mag'] < 15)

pandacat2 = pandacat[criteria].where(np.isnan(pandacat.parallax)==False).dropna(how='all').reset_index(drop=True)
table2 = QTable.from_pandas(pandacat2, index=True)


table2.sort('ra')
table2
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]
# <QTable length=16>
# index         dist         ...                                     datalink_url
# int64       float64        ...                                        str83
# ----- -------------------- ... -----------------------------------------------------------------------------------
#    15 0.037156784225547836 ... https://gea.esac.esa.int/data-server/datalink/links?ID=Gaia+DR2+3426279034760282368
#     8 0.019907548770815506 ... https://gea.esac.esa.int/data-server/datalink/links?ID=Gaia+DR2+3426276079822787968
#     9 0.023770927007721484 ... https://gea.esac.esa.int/data-server/datalink/links?ID=Gaia+DR2+3426275701865671424
#     7  0.01832663454572093 ... https://gea.esac.esa.int/data-server/datalink/links?ID=Gaia+DR2+3426276109883831680
#    11  0.02522824715714728 ... https://gea.esac.esa.int/data-server/datalink/links?ID=Gaia+DR2+3426276114182514176
#    12  0.02754638011120288 ... https://gea.esac.esa.int/data-server/datalink/links?ID=Gaia+DR2+3426281989697772800
#    14 0.029887079302753874 ... https://gea.esac.esa.int/data-server/datalink/links?ID=Gaia+DR2+3426281989697771648
#     6 0.017148668693582555 ... https://gea.esac.esa.int/data-server/datalink/links?ID=Gaia+DR2+3426276045463037312
#    10 0.024495030823210504 ... https://gea.esac.esa.int/data-server/datalink/links?ID=Gaia+DR2+3426281989697769344
#     3 0.012740481198662943 ... https://gea.esac.esa.int/data-server/datalink/links?ID=Gaia+DR2+3426281920978296448
#     1 0.006400577609515265 ... https://gea.esac.esa.int/data-server/datalink/links?ID=Gaia+DR2+3426275839304608896
#     0 0.005928496705287895 ... https://gea.esac.esa.int/data-server/datalink/links?ID=Gaia+DR2+3426275839304609920
#     2 0.009403858167588507 ... https://gea.esac.esa.int/data-server/datalink/links?ID=Gaia+DR2+3426275839304606976
#     4 0.013225957811239697 ... https://gea.esac.esa.int/data-server/datalink/links?ID=Gaia+DR2+3426281714819865472
#     5 0.016206568913798132 ... https://gea.esac.esa.int/data-server/datalink/links?ID=Gaia+DR2+3426281714819863424
#    13  0.02774452736977051 ... https://gea.esac.esa.int/data-server/datalink/links?ID=Gaia+DR2+3426275770585129984

# %% [markdown]
# # Now show the selected Gaia stars in the aladin viewer.
#
# You can also change the center of our field of view and redo the query if you want.

# %%
import ipyaladin.aladin_widget as ipyal
importlib.reload(ipyal)

aladin = ipyal.Aladin(target=coords.to_string(), fov=0.06,survey='dss')


aladin
# Out:
# Aladin(fov=0.06, options=['allow_full_zoomout', 'coo_frame', 'fov', 'full_screen', 'log', 'overlay_survey', 'o…

# %%
#then overplot stars in our selected group

#need to create new gaia table or else it won't show for some reason
aladin_table = QTable(table2[['index','ra','ra_error','dec', 'dec_error', 'parallax', 'parallax_error']])

aladin.add_table(aladin_table)

# %% [markdown]
# # Find center coordinates of target field
#
# Now that we have selected some stars in the general FoV from our initial coordinates, find the center coordinates of these selected stars to get a target center for the CCD. FoV is ~3.1$'$=186$''$ according to SAMI manual.
#
# Generally, we want to know where we should point the telescope such that those pointing coordinates fall in the center of our CCD.
#
# Right now, I am assuming that the telescope pointing will correspond to the center of our CCD.  This will be adjusted/fine-tuned when we run tests at SOAR.

# %%
RA_Center = (np.max(table2['ra'])-np.min(table2['ra'])) /2. + np.min(table2['ra'])


DEC_Center = (np.max(table2['dec'])-np.min(table2['dec'])) /2. + np.min(table2['dec'])

targ_center_coords = SkyCoord(RA_Center,DEC_Center,unit=u.deg,frame='icrs')
print(RA_Center, DEC_Center)
# Out:
# 92.0335248720921 24.353934677036822

# %%
# From these center coordinates, we want to get the edges of the ~3' x 3' field of view, since not all of the 
# selected stars will be within that frame.

RA_max = RA_Center + 1.5/60.  # 1.5' is half of 3' (!)
RA_min = RA_Center - 1.5/60. 
if DEC_Center >= 0:
    DEC_max = DEC_Center + 1.5/60.  
    DEC_min = DEC_Center - 1.5/60.
else:
    DEC_min = -(-DEC_Center + 1.5/60.)  
    DEC_max = -(-DEC_Center - 1.5/60.)


print(RA_max,RA_min,DEC_max,DEC_min)

# Want to make sure selected stars are not within ~5 arcsec of the edges

edge_deg = (5.*u.arcsec).to(u.deg).value


finaltable = table2[(table2['ra']>RA_min+edge_deg) \
                            & (table2['ra']<RA_max-edge_deg) \
                            & (table2['dec']>DEC_min+edge_deg) & (table2['dec']<DEC_max-edge_deg) ]

finaldf = finaltable.to_pandas().drop(columns='index')
len(finaltable)
finaldf
# Out:
# 92.05852487209211 92.0085248720921 24.37893467703682 24.328934677036823
#         dist   solution_id                   DESIGNATION     source_id  \
# 0   0.019908  1.635721e+18  Gaia DR2 3426276079822787968  3.426276e+18
# 1   0.023771  1.635721e+18  Gaia DR2 3426275701865671424  3.426276e+18
# 2   0.018327  1.635721e+18  Gaia DR2 3426276109883831680  3.426276e+18
# 3   0.025228  1.635721e+18  Gaia DR2 3426276114182514176  3.426276e+18
# 4   0.027546  1.635721e+18  Gaia DR2 3426281989697772800  3.426282e+18
# 5   0.029887  1.635721e+18  Gaia DR2 3426281989697771648  3.426282e+18
# 6   0.017149  1.635721e+18  Gaia DR2 3426276045463037312  3.426276e+18
# 7   0.024495  1.635721e+18  Gaia DR2 3426281989697769344  3.426282e+18
# 8   0.012740  1.635721e+18  Gaia DR2 3426281920978296448  3.426282e+18
# 9   0.006401  1.635721e+18  Gaia DR2 3426275839304608896  3.426276e+18
# 10  0.005928  1.635721e+18  Gaia DR2 3426275839304609920  3.426276e+18
# 11  0.009404  1.635721e+18  Gaia DR2 3426275839304606976  3.426276e+18
# 12  0.013226  1.635721e+18  Gaia DR2 3426281714819865472  3.426282e+18
# 13  0.016207  1.635721e+18  Gaia DR2 3426281714819863424  3.426282e+18
#
#     random_index  ref_epoch         ra  ra_error        dec  dec_error  ...  \
# 0   1.241194e+09     2015.5  92.013527  0.022856  24.350910   0.020363  ...
# 1   1.043012e+09     2015.5  92.018255  0.027669  24.330598   0.024889  ...
# 2   1.455207e+09     2015.5  92.022504  0.020356  24.362833   0.018108  ...
# 3   8.830769e+08     2015.5  92.023776  0.100281  24.371611   0.089459  ...
# 4   1.403124e+07     2015.5  92.025493  0.024486  24.374722   0.021456  ...
# 5   6.856610e+08     2015.5  92.025810  0.032554  24.377271   0.028772  ...
# 6   7.215681e+08     2015.5  92.030885  0.164108  24.365329   0.150529  ...
# 7   8.954461e+08     2015.5  92.035511  0.041297  24.373138   0.037638  ...
# 8   8.527982e+08     2015.5  92.041283  0.260510  24.360133   0.247225  ...
# 9   3.875024e+08     2015.5  92.041362  0.033395  24.351779   0.030286  ...
# 10  4.200935e+08     2015.5  92.041540  0.078288  24.350118   0.070667  ...
# 11  3.224019e+08     2015.5  92.043725  0.024372  24.353994   0.021752  ...
# 12  2.953828e+08     2015.5  92.047229  0.039403  24.356098   0.035584  ...
# 13  9.996255e+08     2015.5  92.050200  0.040813  24.357410   0.036803  ...
#
#     e_bp_min_rp_percentile_lower  e_bp_min_rp_percentile_upper  flame_flags  \
# 0                            NaN                           NaN         <NA>
# 1                         0.2803                        0.4680       200111
# 2                            NaN                           NaN       200111
# 3                         0.1459                        0.2431         <NA>
# 4                         0.1426                        1.0068       200111
# 5                         0.2569                        0.4041       200111
# 6                         0.0540                        0.2200       200111
# 7                            NaN                           NaN         <NA>
# 8                            NaN                           NaN         <NA>
# 9                            NaN                           NaN       200111
# 10                           NaN                           NaN       200111
# 11                        0.1139                        0.5641       200111
# 12                           NaN                           NaN         <NA>
# 13                        0.2189                        0.2861       200111
#
#     radius_val  radius_percentile_lower  radius_percentile_upper    lum_val  \
# 0          NaN                      NaN                      NaN        NaN
# 1     1.382691                 1.054829                 1.453287   1.251331
# 2     3.539055                 3.187183                 3.812821  43.811123
# 3          NaN                      NaN                      NaN        NaN
# 4     7.607296                 7.209239                 8.712514  27.059584
# 5     1.102781                 0.868079                 1.227294   0.879096
# 6     0.574874                 0.533937                 0.608575   0.088056
# 7          NaN                      NaN                      NaN        NaN
# 8          NaN                      NaN                      NaN        NaN
# 9     4.965346                 4.295956                 5.157484   9.207450
# 10    1.326780                 1.250911                 1.511868   0.900291
# 11    2.574644                 2.407250                 2.825387  10.188472
# 12         NaN                      NaN                      NaN        NaN
# 13    0.878462                 0.825757                 0.922991   0.396075
#
#     lum_percentile_lower  lum_percentile_upper  \
# 0                    NaN                   NaN
# 1               1.147841              1.354822
# 2              34.805885             52.816360
# 3                    NaN                   NaN
# 4              21.774876             32.344292
# 5               0.805431              0.952761
# 6               0.079068              0.097045
# 7                    NaN                   NaN
# 8                    NaN                   NaN
# 9               6.632379             11.782521
# 10              0.774130              1.026452
# 11              8.704852             11.672091
# 12                   NaN                   NaN
# 13              0.362275              0.429875
#
#                                          datalink_url
# 0   https://gea.esac.esa.int/data-server/datalink/...
# 1   https://gea.esac.esa.int/data-server/datalink/...
# 2   https://gea.esac.esa.int/data-server/datalink/...
# 3   https://gea.esac.esa.int/data-server/datalink/...
# 4   https://gea.esac.esa.int/data-server/datalink/...
# 5   https://gea.esac.esa.int/data-server/datalink/...
# 6   https://gea.esac.esa.int/data-server/datalink/...
# 7   https://gea.esac.esa.int/data-server/datalink/...
# 8   https://gea.esac.esa.int/data-server/datalink/...
# 9   https://gea.esac.esa.int/data-server/datalink/...
# 10  https://gea.esac.esa.int/data-server/datalink/...
# 11  https://gea.esac.esa.int/data-server/datalink/...
# 12  https://gea.esac.esa.int/data-server/datalink/...
# 13  https://gea.esac.esa.int/data-server/datalink/...
#
# [14 rows x 96 columns]

# %%
# create a new WCS, but use the DMD scalings/rotations

DMD_Scale = (3.095*60)/1080
crmirror1 = 540  # center x of 1080x1080 DMD array
# really the array is 2048x1080 but we'll restrict it to mirrors within the FoV)
crmirror2 = 540 # center y of 1080x1080 DMD array

dmd_wcs = sof.create_wcs(pixscale1=DMD_Scale,pixscale2=DMD_Scale, pos_angle=0., naxis1=1080, naxis2=1080,
                     crval1=RA_Center, crval2=DEC_Center, crpix1=crmirror1, crpix2=crmirror2)


print(RA_Center, DEC_Center)
dmd_wcs
# Out:
# 92.0335248720921 24.353934677036822
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 92.0335248720921  24.35393467703682
# CRPIX : 540.0  540.0
# CD1_1 CD1_2  : -4.7762345679012e-05  0.0
# CD2_1 CD2_2  : -0.0  4.77623456790123e-05
# NAXIS : 1080  1080

# %%
# We can now convert the sky coordinates RA and DEC to pixel coordinates using the WCS

pixcoords = np.asarray([skycoord_to_pixel(wcs=dmd_wcs,
                                    coords= SkyCoord(finaldf.loc[i,"ra"],
                                    finaldf.loc[i,"dec"], unit="deg")) for i in finaldf.index])

finaldf["x"] = pixcoords[:,0]
finaldf["y"] = pixcoords[:,1]

finaldf
# Out:
#         dist   solution_id                   DESIGNATION     source_id  \
# 0   0.019908  1.635721e+18  Gaia DR2 3426276079822787968  3.426276e+18
# 1   0.023771  1.635721e+18  Gaia DR2 3426275701865671424  3.426276e+18
# 2   0.018327  1.635721e+18  Gaia DR2 3426276109883831680  3.426276e+18
# 3   0.025228  1.635721e+18  Gaia DR2 3426276114182514176  3.426276e+18
# 4   0.027546  1.635721e+18  Gaia DR2 3426281989697772800  3.426282e+18
# 5   0.029887  1.635721e+18  Gaia DR2 3426281989697771648  3.426282e+18
# 6   0.017149  1.635721e+18  Gaia DR2 3426276045463037312  3.426276e+18
# 7   0.024495  1.635721e+18  Gaia DR2 3426281989697769344  3.426282e+18
# 8   0.012740  1.635721e+18  Gaia DR2 3426281920978296448  3.426282e+18
# 9   0.006401  1.635721e+18  Gaia DR2 3426275839304608896  3.426276e+18
# 10  0.005928  1.635721e+18  Gaia DR2 3426275839304609920  3.426276e+18
# 11  0.009404  1.635721e+18  Gaia DR2 3426275839304606976  3.426276e+18
# 12  0.013226  1.635721e+18  Gaia DR2 3426281714819865472  3.426282e+18
# 13  0.016207  1.635721e+18  Gaia DR2 3426281714819863424  3.426282e+18
#
#     random_index  ref_epoch         ra  ra_error        dec  dec_error  ...  \
# 0   1.241194e+09     2015.5  92.013527  0.022856  24.350910   0.020363  ...
# 1   1.043012e+09     2015.5  92.018255  0.027669  24.330598   0.024889  ...
# 2   1.455207e+09     2015.5  92.022504  0.020356  24.362833   0.018108  ...
# 3   8.830769e+08     2015.5  92.023776  0.100281  24.371611   0.089459  ...
# 4   1.403124e+07     2015.5  92.025493  0.024486  24.374722   0.021456  ...
# 5   6.856610e+08     2015.5  92.025810  0.032554  24.377271   0.028772  ...
# 6   7.215681e+08     2015.5  92.030885  0.164108  24.365329   0.150529  ...
# 7   8.954461e+08     2015.5  92.035511  0.041297  24.373138   0.037638  ...
# 8   8.527982e+08     2015.5  92.041283  0.260510  24.360133   0.247225  ...
# 9   3.875024e+08     2015.5  92.041362  0.033395  24.351779   0.030286  ...
# 10  4.200935e+08     2015.5  92.041540  0.078288  24.350118   0.070667  ...
# 11  3.224019e+08     2015.5  92.043725  0.024372  24.353994   0.021752  ...
# 12  2.953828e+08     2015.5  92.047229  0.039403  24.356098   0.035584  ...
# 13  9.996255e+08     2015.5  92.050200  0.040813  24.357410   0.036803  ...
#
#     flame_flags  radius_val  radius_percentile_lower  radius_percentile_upper  \
# 0          <NA>         NaN                      NaN                      NaN
# 1        200111    1.382691                 1.054829                 1.453287
# 2        200111    3.539055                 3.187183                 3.812821
# 3          <NA>         NaN                      NaN                      NaN
# 4        200111    7.607296                 7.209239                 8.712514
# 5        200111    1.102781                 0.868079                 1.227294
# 6        200111    0.574874                 0.533937                 0.608575
# 7          <NA>         NaN                      NaN                      NaN
# 8          <NA>         NaN                      NaN                      NaN
# 9        200111    4.965346                 4.295956                 5.157484
# 10       200111    1.326780                 1.250911                 1.511868
# 11       200111    2.574644                 2.407250                 2.825387
# 12         <NA>         NaN                      NaN                      NaN
# 13       200111    0.878462                 0.825757                 0.922991
#
#       lum_val  lum_percentile_lower  lum_percentile_upper  \
# 0         NaN                   NaN                   NaN
# 1    1.251331              1.147841              1.354822
# 2   43.811123             34.805885             52.816360
# 3         NaN                   NaN                   NaN
# 4   27.059584             21.774876             32.344292
# 5    0.879096              0.805431              0.952761
# 6    0.088056              0.079068              0.097045
# 7         NaN                   NaN                   NaN
# 8         NaN                   NaN                   NaN
# 9    9.207450              6.632379             11.782521
# 10   0.900291              0.774130              1.026452
# 11  10.188472              8.704852             11.672091
# 12        NaN                   NaN                   NaN
# 13   0.396075              0.362275              0.429875
#
#                                          datalink_url           x            y
# 0   https://gea.esac.esa.int/data-server/datalink/...  920.442011   475.706055
# 1   https://gea.esac.esa.int/data-server/datalink/...  830.311388    50.420097
# 2   https://gea.esac.esa.int/data-server/datalink/...  749.193520   725.316686
# 3   https://gea.esac.esa.int/data-server/datalink/...  724.928818   909.093181
# 4   https://gea.esac.esa.int/data-server/datalink/...  692.171754   974.220339
# 5   https://gea.esac.esa.int/data-server/datalink/...  686.133173  1027.599985
# 6   https://gea.esac.esa.int/data-server/datalink/...  589.341478   777.555619
# 7   https://gea.esac.esa.int/data-server/datalink/...  501.115726   941.063051
# 8   https://gea.esac.esa.int/data-server/datalink/...  391.033659   668.770988
# 9   https://gea.esac.esa.int/data-server/datalink/...  389.511856   493.867550
# 10  https://gea.esac.esa.int/data-server/datalink/...  386.121700   459.095855
# 11  https://gea.esac.esa.int/data-server/datalink/...  344.435441   540.259272
# 12  https://gea.esac.esa.int/data-server/datalink/...  277.610042   584.309080
# 13  https://gea.esac.esa.int/data-server/datalink/...  220.956341   611.776552
#
# [14 rows x 98 columns]

# %% [markdown]
# # Download an image from the HiPS server
#
# Image should have the same size/scalings/wcs as DMD so we can select stars and see what the pattern will look like.

# %%
from urllib.parse import urlencode

#get image with DMD params to see how we can get mirrors to match up with stars

hips = '2MASS/J'#'CDS/P/DSS2/red'
#result = hips2fits.query_with_wcs(
#   hips=hips,
#   wcs=w,
#   get_query_payload=False,
#   format='fits',
#   min_cut=0.5,
#   max_cut=99.5,
#   cmap=Colormap('viridis'),
#)
query_params = { 
             'hips': '2MASS/J',
#             'wcs': w, 
             'ra': RA_Center, 
             'dec': DEC_Center,
             'fov': (3.095 * u.arcmin).to(u.deg).value, 
             'projection': 'TAN',
             'width': 1080, 
             'height': 1080 
             }                                                                                               
url = f'http://alasky.u-strasbg.fr/hips-image-services/hips2fits?{urlencode(query_params)}' 
print(url)
hdul = fits.open(url)
hdul.info()
header = hdul[0].header
image = hdul[0].data

#hdul[0].data = np.fliplr(hdul[0].data)
#to save
filename  = "Strasbourg_DMDscale_"+str(np.round(RA_Center,13))+"_"+str(np.round(DEC_Center,13))+".fits"
hdul.writeto(filename,overwrite=True)
print(filename)
#print(header)
print('scale of DSS image: ',header['CDELT2']*3600.,'\n')
# Out:
# http://alasky.u-strasbg.fr/hips-image-services/hips2fits?hips=2MASS%2FJ&ra=92.0335248720921&dec=24.353934677036822&fov=0.051583333333333335&projection=TAN&width=1080&height=1080
# Filename: /Users/danakoeppe/.astropy/cache/download/url/a99e0d9daffcac0c7ea23fcc3d17d75d/contents
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      24   (1080, 1080)   float32
# Strasbourg_DMDscale_92.0335248720921_24.3539346770368.fits
# scale of DSS image:  0.1719444560583132

# %% [markdown]
# # Pick out slits interactively

# %%
from ipywidgets import GridspecLayout

importlib.reload(sof)

# testing slit iterator 
# %matplotlib notebook


sliter = sof.JupyterSlitSizeIterator(df=finaldf, image=image)
# in order to continuously show the updating slit table, 
# we must first initialize JupyterSlitSizeIterator and then
# call the display function to show the table
display(sliter.df_output)

# now start the slit iteration process
sliter()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Output()

# %%
# not only has the slit table been created, but the slits have also been added to the main target table
len(sliter.sl_xsizes)
sliter.df
# Out:
#         dist   solution_id                   DESIGNATION     source_id  \
# 0   0.016207  1.635721e+18  Gaia DR2 3426281714819863424  3.426282e+18
# 1   0.013226  1.635721e+18  Gaia DR2 3426281714819865472  3.426282e+18
# 2   0.009404  1.635721e+18  Gaia DR2 3426275839304606976  3.426276e+18
# 3   0.005928  1.635721e+18  Gaia DR2 3426275839304609920  3.426276e+18
# 4   0.006401  1.635721e+18  Gaia DR2 3426275839304608896  3.426276e+18
# 5   0.012740  1.635721e+18  Gaia DR2 3426281920978296448  3.426282e+18
# 6   0.024495  1.635721e+18  Gaia DR2 3426281989697769344  3.426282e+18
# 7   0.017149  1.635721e+18  Gaia DR2 3426276045463037312  3.426276e+18
# 8   0.029887  1.635721e+18  Gaia DR2 3426281989697771648  3.426282e+18
# 9   0.027546  1.635721e+18  Gaia DR2 3426281989697772800  3.426282e+18
# 10  0.025228  1.635721e+18  Gaia DR2 3426276114182514176  3.426276e+18
# 11  0.018327  1.635721e+18  Gaia DR2 3426276109883831680  3.426276e+18
# 12  0.023771  1.635721e+18  Gaia DR2 3426275701865671424  3.426276e+18
# 13  0.019908  1.635721e+18  Gaia DR2 3426276079822787968  3.426276e+18
#
#     random_index  ref_epoch         ra  ra_error        dec  dec_error  ...  \
# 0   9.996255e+08     2015.5  92.050200  0.040813  24.357410   0.036803  ...
# 1   2.953828e+08     2015.5  92.047229  0.039403  24.356098   0.035584  ...
# 2   3.224019e+08     2015.5  92.043725  0.024372  24.353994   0.021752  ...
# 3   4.200935e+08     2015.5  92.041540  0.078288  24.350118   0.070667  ...
# 4   3.875024e+08     2015.5  92.041362  0.033395  24.351779   0.030286  ...
# 5   8.527982e+08     2015.5  92.041283  0.260510  24.360133   0.247225  ...
# 6   8.954461e+08     2015.5  92.035511  0.041297  24.373138   0.037638  ...
# 7   7.215681e+08     2015.5  92.030885  0.164108  24.365329   0.150529  ...
# 8   6.856610e+08     2015.5  92.025810  0.032554  24.377271   0.028772  ...
# 9   1.403124e+07     2015.5  92.025493  0.024486  24.374722   0.021456  ...
# 10  8.830769e+08     2015.5  92.023776  0.100281  24.371611   0.089459  ...
# 11  1.455207e+09     2015.5  92.022504  0.020356  24.362833   0.018108  ...
# 12  1.043012e+09     2015.5  92.018255  0.027669  24.330598   0.024889  ...
# 13  1.241194e+09     2015.5  92.013527  0.022856  24.350910   0.020363  ...
#
#     radius_percentile_lower  radius_percentile_upper    lum_val  \
# 0                  0.825757                 0.922991   0.396075
# 1                       NaN                      NaN        NaN
# 2                  2.407250                 2.825387  10.188472
# 3                  1.250911                 1.511868   0.900291
# 4                  4.295956                 5.157484   9.207450
# 5                       NaN                      NaN        NaN
# 6                       NaN                      NaN        NaN
# 7                  0.533937                 0.608575   0.088056
# 8                  0.868079                 1.227294   0.879096
# 9                  7.209239                 8.712514  27.059584
# 10                      NaN                      NaN        NaN
# 11                 3.187183                 3.812821  43.811123
# 12                 1.054829                 1.453287   1.251331
# 13                      NaN                      NaN        NaN
#
#     lum_percentile_lower  lum_percentile_upper  \
# 0               0.362275              0.429875
# 1                    NaN                   NaN
# 2               8.704852             11.672091
# 3               0.774130              1.026452
# 4               6.632379             11.782521
# 5                    NaN                   NaN
# 6                    NaN                   NaN
# 7               0.079068              0.097045
# 8               0.805431              0.952761
# 9              21.774876             32.344292
# 10                   NaN                   NaN
# 11             34.805885             52.816360
# 12              1.147841              1.354822
# 13                   NaN                   NaN
#
#                                          datalink_url           x  \
# 0   https://gea.esac.esa.int/data-server/datalink/...  220.956341
# 1   https://gea.esac.esa.int/data-server/datalink/...  277.610042
# 2   https://gea.esac.esa.int/data-server/datalink/...  344.435441
# 3   https://gea.esac.esa.int/data-server/datalink/...  386.121700
# 4   https://gea.esac.esa.int/data-server/datalink/...  389.511856
# 5   https://gea.esac.esa.int/data-server/datalink/...  391.033659
# 6   https://gea.esac.esa.int/data-server/datalink/...  501.115726
# 7   https://gea.esac.esa.int/data-server/datalink/...  589.341478
# 8   https://gea.esac.esa.int/data-server/datalink/...  686.133173
# 9   https://gea.esac.esa.int/data-server/datalink/...  692.171754
# 10  https://gea.esac.esa.int/data-server/datalink/...  724.928818
# 11  https://gea.esac.esa.int/data-server/datalink/...  749.193520
# 12  https://gea.esac.esa.int/data-server/datalink/...  830.311388
# 13  https://gea.esac.esa.int/data-server/datalink/...  920.442011
#
#               y  dx  dy
# 0    611.776552  67   3
# 1    584.309080  64   3
# 2    540.259272  69   3
# 3    459.095855  73   3
# 4    493.867550  66   3
# 5    668.770988  65   3
# 6    941.063051  68   3
# 7    777.555619  64   3
# 8   1027.599985  56   3
# 9    974.220339  82   3
# 10   909.093181  72   3
# 11   725.316686  77   3
# 12    50.420097  69   3
# 13   475.706055  72   3
#
# [14 rows x 100 columns]

# %%
importlib.reload(sof)

np.random.seed(34543)

#sliter.df["dx"] = np.ones(sliter.df.shape[0])*np.random.randint(50)
#sliter.df["dy"] = np.ones(sliter.df.shape[0])*np.random.randint(50)

singledf = pd.DataFrame(data=[sliter.df.iloc[0]],columns=sliter.df.columns)
DMDPattern, dmd_slits, good_index = \
            sof.create_dmd_pattern_from_target_table(sliter.df,wcs=dmd_wcs,
                                                    ra_center=RA_Center,dec_center=DEC_Center,
                                                    slit_xsize=np.asarray(sliter.sl_xsizes),
                                                     slit_ysize=np.asarray(sliter.sl_ysizes))


dmd_slits
# Out:
# length > 1
# accepting first target 0
# append slit 0
# skipping target 1
# accepting target 2
#
#
# append slit 2
# skipping target 3
# skipping target 4
# skipping target 5
# accepting target 6
#
#
# append slit 6
# accepting target 7
#
#
# append slit 7
# accepting target 8
#
#
# append slit 8
# skipping target 9
# skipping target 10
# accepting target 11
#
#
# append slit 11
# accepting target 12
#
#
# append slit 12
# accepting target 13
#
#
# append slit 13
# [<setup_obs_functions.DMDSlit at 0x7fda308d9250>,
#  <setup_obs_functions.DMDSlit at 0x7fda72539050>,
#  <setup_obs_functions.DMDSlit at 0x7fda7252c690>,
#  <setup_obs_functions.DMDSlit at 0x7fda50bb93d0>,
#  <setup_obs_functions.DMDSlit at 0x7fda72669bd0>,
#  <setup_obs_functions.DMDSlit at 0x7fda7266edd0>,
#  <setup_obs_functions.DMDSlit at 0x7fda726805d0>,
#  <setup_obs_functions.DMDSlit at 0x7fda7252bd90>]

# %%
singledf = singledf.drop(labels=[0],axis='index')

len(singledf)
# Out:
# 0

# %%
DMDPattern
# Out:
#                          target       ra      dec        x        y   dx1  \
# 0  Gaia DR2 3426281714819863424  92.0502  24.3574  220.956  611.777  33.5
# 1  Gaia DR2 3426275839304606976  92.0437   24.354  344.435  540.259  34.5
# 2  Gaia DR2 3426281989697769344  92.0355  24.3731  501.116  941.063    34
# 3  Gaia DR2 3426276045463037312  92.0309  24.3653  589.341  777.556    32
# 4  Gaia DR2 3426281989697771648  92.0258  24.3773  686.133   1027.6    28
# 5  Gaia DR2 3426276109883831680  92.0225  24.3628  749.194  725.317  38.5
# 6  Gaia DR2 3426275701865671424  92.0183  24.3306  830.311  50.4201  34.5
# 7  Gaia DR2 3426276079822787968  92.0135  24.3509  920.442  475.706    36
#
#    dy1   dx2  dy2
# 0  1.5  33.5  1.5
# 1  1.5  34.5  1.5
# 2  1.5    34  1.5
# 3  1.5    32  1.5
# 4  1.5    28  1.5
# 5  1.5  38.5  1.5
# 6  1.5  34.5  1.5
# 7  1.5    36  1.5

# %%
sliter.df.sort_values(by="ra")
# Out:
#         dist   solution_id                   DESIGNATION     source_id  \
# 13  0.019908  1.635721e+18  Gaia DR2 3426276079822787968  3.426276e+18
# 12  0.023771  1.635721e+18  Gaia DR2 3426275701865671424  3.426276e+18
# 11  0.018327  1.635721e+18  Gaia DR2 3426276109883831680  3.426276e+18
# 10  0.025228  1.635721e+18  Gaia DR2 3426276114182514176  3.426276e+18
# 9   0.027546  1.635721e+18  Gaia DR2 3426281989697772800  3.426282e+18
# 8   0.029887  1.635721e+18  Gaia DR2 3426281989697771648  3.426282e+18
# 7   0.017149  1.635721e+18  Gaia DR2 3426276045463037312  3.426276e+18
# 6   0.024495  1.635721e+18  Gaia DR2 3426281989697769344  3.426282e+18
# 5   0.012740  1.635721e+18  Gaia DR2 3426281920978296448  3.426282e+18
# 4   0.006401  1.635721e+18  Gaia DR2 3426275839304608896  3.426276e+18
# 3   0.005928  1.635721e+18  Gaia DR2 3426275839304609920  3.426276e+18
# 2   0.009404  1.635721e+18  Gaia DR2 3426275839304606976  3.426276e+18
# 1   0.013226  1.635721e+18  Gaia DR2 3426281714819865472  3.426282e+18
# 0   0.016207  1.635721e+18  Gaia DR2 3426281714819863424  3.426282e+18
#
#     random_index  ref_epoch         ra  ra_error        dec  dec_error  ...  \
# 13  1.241194e+09     2015.5  92.013527  0.022856  24.350910   0.020363  ...
# 12  1.043012e+09     2015.5  92.018255  0.027669  24.330598   0.024889  ...
# 11  1.455207e+09     2015.5  92.022504  0.020356  24.362833   0.018108  ...
# 10  8.830769e+08     2015.5  92.023776  0.100281  24.371611   0.089459  ...
# 9   1.403124e+07     2015.5  92.025493  0.024486  24.374722   0.021456  ...
# 8   6.856610e+08     2015.5  92.025810  0.032554  24.377271   0.028772  ...
# 7   7.215681e+08     2015.5  92.030885  0.164108  24.365329   0.150529  ...
# 6   8.954461e+08     2015.5  92.035511  0.041297  24.373138   0.037638  ...
# 5   8.527982e+08     2015.5  92.041283  0.260510  24.360133   0.247225  ...
# 4   3.875024e+08     2015.5  92.041362  0.033395  24.351779   0.030286  ...
# 3   4.200935e+08     2015.5  92.041540  0.078288  24.350118   0.070667  ...
# 2   3.224019e+08     2015.5  92.043725  0.024372  24.353994   0.021752  ...
# 1   2.953828e+08     2015.5  92.047229  0.039403  24.356098   0.035584  ...
# 0   9.996255e+08     2015.5  92.050200  0.040813  24.357410   0.036803  ...
#
#     radius_percentile_lower  radius_percentile_upper    lum_val  \
# 13                      NaN                      NaN        NaN
# 12                 1.054829                 1.453287   1.251331
# 11                 3.187183                 3.812821  43.811123
# 10                      NaN                      NaN        NaN
# 9                  7.209239                 8.712514  27.059584
# 8                  0.868079                 1.227294   0.879096
# 7                  0.533937                 0.608575   0.088056
# 6                       NaN                      NaN        NaN
# 5                       NaN                      NaN        NaN
# 4                  4.295956                 5.157484   9.207450
# 3                  1.250911                 1.511868   0.900291
# 2                  2.407250                 2.825387  10.188472
# 1                       NaN                      NaN        NaN
# 0                  0.825757                 0.922991   0.396075
#
#     lum_percentile_lower  lum_percentile_upper  \
# 13                   NaN                   NaN
# 12              1.147841              1.354822
# 11             34.805885             52.816360
# 10                   NaN                   NaN
# 9              21.774876             32.344292
# 8               0.805431              0.952761
# 7               0.079068              0.097045
# 6                    NaN                   NaN
# 5                    NaN                   NaN
# 4               6.632379             11.782521
# 3               0.774130              1.026452
# 2               8.704852             11.672091
# 1                    NaN                   NaN
# 0               0.362275              0.429875
#
#                                          datalink_url           x  \
# 13  https://gea.esac.esa.int/data-server/datalink/...  920.442011
# 12  https://gea.esac.esa.int/data-server/datalink/...  830.311388
# 11  https://gea.esac.esa.int/data-server/datalink/...  749.193520
# 10  https://gea.esac.esa.int/data-server/datalink/...  724.928818
# 9   https://gea.esac.esa.int/data-server/datalink/...  692.171754
# 8   https://gea.esac.esa.int/data-server/datalink/...  686.133173
# 7   https://gea.esac.esa.int/data-server/datalink/...  589.341478
# 6   https://gea.esac.esa.int/data-server/datalink/...  501.115726
# 5   https://gea.esac.esa.int/data-server/datalink/...  391.033659
# 4   https://gea.esac.esa.int/data-server/datalink/...  389.511856
# 3   https://gea.esac.esa.int/data-server/datalink/...  386.121700
# 2   https://gea.esac.esa.int/data-server/datalink/...  344.435441
# 1   https://gea.esac.esa.int/data-server/datalink/...  277.610042
# 0   https://gea.esac.esa.int/data-server/datalink/...  220.956341
#
#               y  dx  dy
# 13   475.706055  72   3
# 12    50.420097  69   3
# 11   725.316686  77   3
# 10   909.093181  72   3
# 9    974.220339  82   3
# 8   1027.599985  56   3
# 7    777.555619  64   3
# 6    941.063051  68   3
# 5    668.770988  65   3
# 4    493.867550  66   3
# 3    459.095855  73   3
# 2    540.259272  69   3
# 1    584.309080  64   3
# 0    611.776552  67   3
#
# [14 rows x 100 columns]

# %%
importlib.reload(sof)

newtargdf = sliter.df.copy()
newtargdf["dx"] = np.ones(sliter.df.shape[0])*7.
newtargdf["dy"] = np.ones(sliter.df.shape[0])*3.
pattern_tables, slits_lists = \
            sof.DMDPatternsMaker(sliter.df,wcs=dmd_wcs,ra_center=RA_Center,dec_center=DEC_Center)
# Out:
# creating DMD pattern 1
# length > 1
# accepting first target 0
# append slit 0
# skipping target 1
# accepting target 2
#
#
# append slit 2
# skipping target 3
# skipping target 4
# skipping target 5
# accepting target 6
#
#
# append slit 6
# accepting target 7
#
#
# append slit 7
# accepting target 8
#
#
# append slit 8
# skipping target 9
# skipping target 10
# accepting target 11
#
#
# append slit 11
# accepting target 12
#
#
# append slit 12
# accepting target 13
#
#
# append slit 13
# pattern table made 6 to go
# creating DMD pattern 2
# length > 1
# accepting first target 0
# append slit 0
# accepting target 1
#
#
# append slit 1
# skipping target 2
# skipping target 3
# accepting target 4
#
#
# append slit 4
# accepting target 5
#
#
# append slit 5
# pattern table made 2 to go
# creating DMD pattern 3
# length > 1
# accepting first target 0
# append slit 0
# accepting target 1
#
#
# append slit 1
# pattern table made 0 to go
# 3 DMD patterns created

# %%
config1 = pattern_tables[2]

config1.to_csv("test_pattern3_92.03352_24.35393")

# %%
"{:.5f}_{:.5f}".format(RA_Center,DEC_Center)

pattern_tables[2]
# Out:
#                          target       ra      dec        x        y   dx1  \
# 0  Gaia DR2 3426275839304608896  92.0414  24.3518  389.512  493.868    33
# 1  Gaia DR2 3426281920978296448  92.0413  24.3601  391.034  668.771  32.5
#
#    dy1   dx2  dy2
# 0  1.5    33  1.5
# 1  1.5  32.5  1.5

# %%
dfcopy = sliter.df.copy()


dfcopy = dfcopy.drop(labels=[0],axis='index')

pattern_tables[0]
# Out:
#                           target       ra      dec        x        y  dx1  \
# 0   Gaia DR2 3426281714819863424  92.0502  24.3574  220.956  611.777  3.5
# 1   Gaia DR2 3426281714819865472  92.0472  24.3561   277.61  584.309  3.5
# 2   Gaia DR2 3426275839304606976  92.0437   24.354  344.435  540.259  3.5
# 3   Gaia DR2 3426275839304609920  92.0415  24.3501  386.122  459.096  3.5
# 4   Gaia DR2 3426281989697769344  92.0355  24.3731  501.116  941.063  3.5
# 5   Gaia DR2 3426276045463037312  92.0309  24.3653  589.341  777.556  3.5
# 6   Gaia DR2 3426281989697771648  92.0258  24.3773  686.133   1027.6  3.5
# 7   Gaia DR2 3426276114182514176  92.0238  24.3716  724.929  909.093  3.5
# 8   Gaia DR2 3426276109883831680  92.0225  24.3628  749.194  725.317  3.5
# 9   Gaia DR2 3426275701865671424  92.0183  24.3306  830.311  50.4201  3.5
# 10  Gaia DR2 3426276079822787968  92.0135  24.3509  920.442  475.706  3.5
#
#     dy1  dx2  dy2
# 0   1.5  3.5  1.5
# 1   1.5  3.5  1.5
# 2   1.5  3.5  1.5
# 3   1.5  3.5  1.5
# 4   1.5  3.5  1.5
# 5   1.5  3.5  1.5
# 6   1.5  3.5  1.5
# 7   1.5  3.5  1.5
# 8   1.5  3.5  1.5
# 9   1.5  3.5  1.5
# 10  1.5  3.5  1.5

# %%
slits_lists[-2][0].slit_n
# Out:
# 0

# %%
sliter.df
# Out:
#         dist   solution_id                   DESIGNATION     source_id  \
# 0   0.016207  1.635721e+18  Gaia DR2 3426281714819863424  3.426282e+18
# 1   0.013226  1.635721e+18  Gaia DR2 3426281714819865472  3.426282e+18
# 2   0.009404  1.635721e+18  Gaia DR2 3426275839304606976  3.426276e+18
# 3   0.005928  1.635721e+18  Gaia DR2 3426275839304609920  3.426276e+18
# 4   0.006401  1.635721e+18  Gaia DR2 3426275839304608896  3.426276e+18
# 5   0.012740  1.635721e+18  Gaia DR2 3426281920978296448  3.426282e+18
# 6   0.024495  1.635721e+18  Gaia DR2 3426281989697769344  3.426282e+18
# 7   0.017149  1.635721e+18  Gaia DR2 3426276045463037312  3.426276e+18
# 8   0.029887  1.635721e+18  Gaia DR2 3426281989697771648  3.426282e+18
# 9   0.027546  1.635721e+18  Gaia DR2 3426281989697772800  3.426282e+18
# 10  0.025228  1.635721e+18  Gaia DR2 3426276114182514176  3.426276e+18
# 11  0.018327  1.635721e+18  Gaia DR2 3426276109883831680  3.426276e+18
# 12  0.023771  1.635721e+18  Gaia DR2 3426275701865671424  3.426276e+18
# 13  0.019908  1.635721e+18  Gaia DR2 3426276079822787968  3.426276e+18
#
#     random_index  ref_epoch         ra  ra_error        dec  dec_error  ...  \
# 0   9.996255e+08     2015.5  92.050200  0.040813  24.357410   0.036803  ...
# 1   2.953828e+08     2015.5  92.047229  0.039403  24.356098   0.035584  ...
# 2   3.224019e+08     2015.5  92.043725  0.024372  24.353994   0.021752  ...
# 3   4.200935e+08     2015.5  92.041540  0.078288  24.350118   0.070667  ...
# 4   3.875024e+08     2015.5  92.041362  0.033395  24.351779   0.030286  ...
# 5   8.527982e+08     2015.5  92.041283  0.260510  24.360133   0.247225  ...
# 6   8.954461e+08     2015.5  92.035511  0.041297  24.373138   0.037638  ...
# 7   7.215681e+08     2015.5  92.030885  0.164108  24.365329   0.150529  ...
# 8   6.856610e+08     2015.5  92.025810  0.032554  24.377271   0.028772  ...
# 9   1.403124e+07     2015.5  92.025493  0.024486  24.374722   0.021456  ...
# 10  8.830769e+08     2015.5  92.023776  0.100281  24.371611   0.089459  ...
# 11  1.455207e+09     2015.5  92.022504  0.020356  24.362833   0.018108  ...
# 12  1.043012e+09     2015.5  92.018255  0.027669  24.330598   0.024889  ...
# 13  1.241194e+09     2015.5  92.013527  0.022856  24.350910   0.020363  ...
#
#     radius_percentile_lower  radius_percentile_upper    lum_val  \
# 0                  0.825757                 0.922991   0.396075
# 1                       NaN                      NaN        NaN
# 2                  2.407250                 2.825387  10.188472
# 3                  1.250911                 1.511868   0.900291
# 4                  4.295956                 5.157484   9.207450
# 5                       NaN                      NaN        NaN
# 6                       NaN                      NaN        NaN
# 7                  0.533937                 0.608575   0.088056
# 8                  0.868079                 1.227294   0.879096
# 9                  7.209239                 8.712514  27.059584
# 10                      NaN                      NaN        NaN
# 11                 3.187183                 3.812821  43.811123
# 12                 1.054829                 1.453287   1.251331
# 13                      NaN                      NaN        NaN
#
#     lum_percentile_lower  lum_percentile_upper  \
# 0               0.362275              0.429875
# 1                    NaN                   NaN
# 2               8.704852             11.672091
# 3               0.774130              1.026452
# 4               6.632379             11.782521
# 5                    NaN                   NaN
# 6                    NaN                   NaN
# 7               0.079068              0.097045
# 8               0.805431              0.952761
# 9              21.774876             32.344292
# 10                   NaN                   NaN
# 11             34.805885             52.816360
# 12              1.147841              1.354822
# 13                   NaN                   NaN
#
#                                          datalink_url           x  \
# 0   https://gea.esac.esa.int/data-server/datalink/...  220.956341
# 1   https://gea.esac.esa.int/data-server/datalink/...  277.610042
# 2   https://gea.esac.esa.int/data-server/datalink/...  344.435441
# 3   https://gea.esac.esa.int/data-server/datalink/...  386.121700
# 4   https://gea.esac.esa.int/data-server/datalink/...  389.511856
# 5   https://gea.esac.esa.int/data-server/datalink/...  391.033659
# 6   https://gea.esac.esa.int/data-server/datalink/...  501.115726
# 7   https://gea.esac.esa.int/data-server/datalink/...  589.341478
# 8   https://gea.esac.esa.int/data-server/datalink/...  686.133173
# 9   https://gea.esac.esa.int/data-server/datalink/...  692.171754
# 10  https://gea.esac.esa.int/data-server/datalink/...  724.928818
# 11  https://gea.esac.esa.int/data-server/datalink/...  749.193520
# 12  https://gea.esac.esa.int/data-server/datalink/...  830.311388
# 13  https://gea.esac.esa.int/data-server/datalink/...  920.442011
#
#               y  dx  dy
# 0    611.776552  61   3
# 1    584.309080  71   3
# 2    540.259272  69   3
# 3    459.095855  81   3
# 4    493.867550  44   3
# 5    668.770988   7   3
# 6    941.063051   7   3
# 7    777.555619   7   3
# 8   1027.599985   7   3
# 9    974.220339   7   3
# 10   909.093181  70   3
# 11   725.316686  77   3
# 12    50.420097  69   3
# 13   475.706055  73   3
#
# [14 rows x 100 columns]

# %%
from ipywidgets import AppLayout, Button
from ipywidgets import HTML, Layout, Dropdown, Output, Textarea, VBox, Label, HBox
from IPython.display import display, HTML

# %matplotlib inline

#plt.ioff()
gs = GridspecLayout(1,2)

out = widgets.Output(layout={'border': '1px solid black', 'position':'right'})
figout = widgets.Output()

fig1 = plt.figure(figsize=(10,8))#, layout='tight')
out_txt = "{}"
slitsdf = sliter.df.copy()
cell_text = []
with out:
    #print("RA DEC X Y dX dY")
    sldf =  pd.DataFrame(columns=slitsdf.columns)
    #display(HTML(sldf.to_html()))
    for i in slitsdf.index.values:
        #print(display(HTML(finaldf.to_html())))
        row = slitsdf.iloc[i]
        sldf.loc[i] = row.values
        #print(display(HTML(sldf.to_html(header=False))))
        #print(out_txt.format(row.ra,row.dec, row.x, row.y, row.dx, row.dy))
        rowvals = [row.ra.round(8),row.dec.round(8), row.x.round(3), row.y.round(3), row.dx, row.dy]
        print(rowvals)
        cell_text.append([out_txt.format(val) for val in rowvals])
        print(i)

with figout:
    ax1 = fig1.add_subplot(111)#(gs[0,0])  

#with plt.ioff():
#print(cell_text)
#cell_text.append([[out_txt.format(val) for val in [slitsdf.loc[i, "ra"], 
#                  slitsdf.loc[i, "dec"], slitsdf.loc[i, "x"], slitsdf.loc[i, "y"],
#                  slitsdf.loc[i, "dx"],slitsdf.loc[i, "dy"]]] for i in slitsdf.index])
print(cell_text)
rowlabels = ["slit {:03n}".format(i+1) for i in range(slitsdf.shape[0])]
the_table = ax1.table(cellText=cell_text,bbox=(1.5,0,2,1),figure=fig1, 
                      colWidths=[0.1, 0.1, 0.1, 0.1, 0.05, 0.05],
                      in_layout=True,rowLabels=rowlabels,
                      colLabels=["RA", "DEC", "X", "Y", "dX", "dY"],loc="right")

the_table.auto_set_font_size(False)
the_table.set_fontsize(25)

the_table[1,4].set_text_props(text='30')


cell0_width = the_table[1,0].get_width()
cell0_height = the_table[1,0].get_height()

cell1_width = the_table[1,1].get_width()
cell1_height = the_table[1,1].get_height()

cell2_width = the_table[1,2].get_width()
cell2_height = the_table[1,2].get_height()

cell3_width = the_table[1,3].get_width()
cell3_height = the_table[1,3].get_height()

cell4_width = the_table[1,4].get_width()
cell4_height = the_table[1,4].get_height()

cell5_width = the_table[1,5].get_width()
cell5_height = the_table[1,5].get_height()

print(cell1_width)
print(len(cell_text))
rown = "{:03n}".format(len(cell_text))
the_table.add_cell(text=rown,row=len(cell_text)+1, col=-1, width=cell0_width, height=cell0_height)

the_table.add_cell(text="test",row=len(cell_text)+1, col=0, width=cell0_width, height=cell0_height)
the_table.add_cell(row=len(cell_text)+1, col=1, width=cell1_width, height=cell1_height)
the_table.add_cell(row=len(cell_text)+1, col=2, width=cell2_width, height=cell2_height, )

the_table.rowLabels = rowlabels.append(rown)
rowlabels.append(rown)
the_table[len(cell_text)+1,0].set_label(rowlabels)
#set(label=rowlabels.append(rown))
with figout:
    im1 = ax1.imshow(image, origin='lower',cmap='gray',norm=hipsnorm,)#extent=[-512, 512, -512, 512])
    #display(fig1.canvas)
    ax1.tick_params(labelsize=25)
    plt.show(fig1)
    plt.show(the_table)


#display(figout)
gs[0,1] = out
gs[0,0] = figout



figout
# Out:
# [['92.05019959', '24.35740974', '220.956', '611.777', '15.0', '38.0'], ['92.04722915', '24.35609813', '277.61', '584.309', '15.0', '38.0'], ['92.04372543', '24.35399448', '344.435', '540.259', '15.0', '38.0'], ['92.04153967', '24.35011806', '386.122', '459.096', '15.0', '38.0'], ['92.04136204', '24.35177884', '389.512', '493.868', '15.0', '38.0'], ['92.04128277', '24.36013265', '391.034', '668.771', '15.0', '38.0'], ['92.03551135', '24.37313814', '501.116', '941.063', '15.0', '38.0'], ['92.03088535', '24.36532863', '589.341', '777.556', '15.0', '38.0'], ['92.02580961', '24.37727116', '686.133', '1027.6', '15.0', '38.0'], ['92.02549313', '24.37472161', '692.172', '974.22', '15.0', '38.0'], ['92.02377571', '24.37161088', '724.929', '909.093', '15.0', '38.0'], ['92.02250416', '24.3628332', '749.194', '725.317', '15.0', '38.0'], ['92.01825493', '24.33059819', '830.311', '50.42', '15.0', '38.0'], ['92.01352727', '24.3509103', '920.442', '475.706', '15.0', '38.0']]
# 0.1
# 14
# Output(layout=Layout(grid_area='widget002'))

# %%
cell1 = the_table.get_children()[0]
print(cell1.get_text())

the_table
# Out:
# Text(886.5768000000003, 432.30999999999995, '92.05019959')

# %%
for c in the_table.get_celld().values():
    #print(c.get_bbox())
    print(c)
# Out:
# Rectangle(xy=(1.5, 0.875), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(1.9, 0.875), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.3, 0.875), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.7, 0.875), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(3.1, 0.875), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(3.3, 0.875), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(1.5, 0.8125), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(1.9, 0.8125), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.3, 0.8125), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.7, 0.8125), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(3.1, 0.8125), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(3.3, 0.8125), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(1.5, 0.75), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(1.9, 0.75), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.3, 0.75), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.7, 0.75), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(3.1, 0.75), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(3.3, 0.75), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(1.5, 0.6875), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(1.9, 0.6875), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.3, 0.6875), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.7, 0.6875), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(3.1, 0.6875), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(3.3, 0.6875), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(1.5, 0.625), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(1.9, 0.625), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.3, 0.625), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.7, 0.625), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(3.1, 0.625), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(3.3, 0.625), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(1.5, 0.5625), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(1.9, 0.5625), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.3, 0.5625), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.7, 0.5625), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(3.1, 0.5625), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(3.3, 0.5625), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(1.5, 0.5), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(1.9, 0.5), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.3, 0.5), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.7, 0.5), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(3.1, 0.5), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(3.3, 0.5), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(1.5, 0.4375), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(1.9, 0.4375), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.3, 0.4375), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.7, 0.4375), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(3.1, 0.4375), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(3.3, 0.4375), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(1.5, 0.375), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(1.9, 0.375), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.3, 0.375), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.7, 0.375), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(3.1, 0.375), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(3.3, 0.375), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(1.5, 0.3125), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(1.9, 0.3125), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.3, 0.3125), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.7, 0.3125), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(3.1, 0.3125), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(3.3, 0.3125), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(1.5, 0.25), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(1.9, 0.25), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.3, 0.25), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.7, 0.25), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(3.1, 0.25), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(3.3, 0.25), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(1.5, 0.1875), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(1.9, 0.1875), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.3, 0.1875), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.7, 0.1875), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(3.1, 0.1875), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(3.3, 0.1875), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(1.5, 0.125), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(1.9, 0.125), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.3, 0.125), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.7, 0.125), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(3.1, 0.125), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(3.3, 0.125), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(1.5, 0.0625), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(1.9, 0.0625), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.3, 0.0625), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.7, 0.0625), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(3.1, 0.0625), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(3.3, 0.0625), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(1.5, 0.9375), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(1.9, 0.9375), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.3, 0.9375), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.7, 0.9375), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(3.1, 0.9375), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(3.3, 0.9375), width=0.2, height=0.0625, angle=0)
# Rectangle(xy=(1.24476, 0.875), width=0.255243, height=0.0625, angle=0)
# Rectangle(xy=(1.24476, 0.8125), width=0.255243, height=0.0625, angle=0)
# Rectangle(xy=(1.24476, 0.75), width=0.255243, height=0.0625, angle=0)
# Rectangle(xy=(1.24476, 0.6875), width=0.255243, height=0.0625, angle=0)
# Rectangle(xy=(1.24476, 0.625), width=0.255243, height=0.0625, angle=0)
# Rectangle(xy=(1.24476, 0.5625), width=0.255243, height=0.0625, angle=0)
# Rectangle(xy=(1.24476, 0.5), width=0.255243, height=0.0625, angle=0)
# Rectangle(xy=(1.24476, 0.4375), width=0.255243, height=0.0625, angle=0)
# Rectangle(xy=(1.24476, 0.375), width=0.255243, height=0.0625, angle=0)
# Rectangle(xy=(1.24476, 0.3125), width=0.255243, height=0.0625, angle=0)
# Rectangle(xy=(1.24476, 0.25), width=0.255243, height=0.0625, angle=0)
# Rectangle(xy=(1.24476, 0.1875), width=0.255243, height=0.0625, angle=0)
# Rectangle(xy=(1.24476, 0.125), width=0.255243, height=0.0625, angle=0)
# Rectangle(xy=(1.24476, 0.0625), width=0.255243, height=0.0625, angle=0)
# Rectangle(xy=(1.5, 0), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(1.9, 0), width=0.4, height=0.0625, angle=0)
# Rectangle(xy=(2.3, 0), width=0.4, height=0.0625, angle=0)

# %%
cell = the_table[1,4]

cell.set_text_props(text='30')

# %%
cell.get_width()
# Out:
# 0.2

# %%
#import matplotlib.pyplot as plt
#import matplotlib.patches as patches
plt.figure(figsize=(5,5))
plt.plot(RA_Offsets_SPpix, DEC_Offsets_SPpix, 'ro')
plt.axis([-2048, 2048, -2048, 2048])
rectangle = plt.Rectangle((-675,-675),1350, 1350, fc='blue',ec="red")
plt.gca().add_patch(rectangle)
for i in range(len(RA_Offsets_IMpix)):
#    print(RA_Offsets_IMpix.iloc[i])
#    print(np.round(RA_Offsets_IMpix.iloc[i]-1),np.round(DEC_Offsets_IMpix.iloc[i]-1000,3, np.round(DEC_Offsets_IMpix.iloc[i]+1000))
    xy = (RA_Offsets_SPpix.iloc[i]-1,np.round(DEC_Offsets_SPpix.iloc[i]-1000))
    rectangle = plt.Rectangle(xy ,7, np.round(DEC_Offsets_SPpix.iloc[i]+2000), fc='green',ec="green")
    plt.gca().add_patch(rectangle)
plt.show()
